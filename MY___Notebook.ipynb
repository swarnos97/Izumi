# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <H1> My Jupyter Notebook on IBM Watson Studio </H1>

# %% [markdown]
# <B> SWARNALI SARKAR </B>
#
# ESCALATION SUPERVISOR

# %% [markdown]
# <i> I am  interested in Data Science because I studied statistics in my graduation and want to know more about working with data. </i>

# %% [markdown]
# <H3> In the following code I'll do a very simple mathematical operation. </H3>

# %%
6/2*4+3-5
# Out:
# 10.0

# %% [markdown]
# |header|header|
# |------|------|
# | cell | cell |
# | cell | cell |
# | cell | cell |
#
#
#
#
# <s> To do list </s>
#
#
# + submit your assignment
# + grade your peer
# + complete final exam
# + earn badge2
